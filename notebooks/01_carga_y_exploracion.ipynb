# %%
# Verificación de versión de Python y bibliotecas principales
import sys
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

print(f"Versión de Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")

# %%
# Carga del archivo de datos desde la carpeta data/ (o mediante la carga local de Colab)
# Ejemplo: si subes tu archivo ventas_autopartes.csv
df = pd.read_csv('../data/ventas_autopartes.csv') # Ajusta la ruta según tu estructura

# 1. Dimensiones del conjunto de datos
print("=== DIMENSIONES DEL DATASET ===")
print(f"Filas: {df.shape[0]} | Columnas: {df.shape[1]}\n")

# 2. Primeras filas
print("=== PRIMERAS FILAS (HEAD) ===")
display(df.head())
