# %%
import sys
import pandas as pd
import sklearn
import matplotlib.pyplot as plt

print(f"Versión de Python: {sys.version}")
print(f"Pandas: {pd.__version__}")
print(f"Scikit-learn: {sklearn.__version__}")
# Out:
# Versión de Python: 3.13.15 (main, Aug  6 2026, 11:06:22) [GCC 13.3.0]
# Pandas: 2.2.3
# Scikit-learn: 1.6.1

# %%
df = pd.read_csv('./sample_data/ventas_autopartes.csv')

print("=== DIMENSIONES DEL DATASET ===")
print(f"Filas: {df.shape[0]} | Columnas: {df.shape[1]}\n")

print("=== PRIMERAS FILAS (HEAD) ===")
display(df.head())
# Out:
# === DIMENSIONES DEL DATASET ===
# Filas: 1053 | Columnas: 5
#
# === PRIMERAS FILAS (HEAD) ===
#         fecha  storeId  productId  precioventa  cantidadventdida
# 0  2022-08-08        1          1        300.0                 5
# 1  2022-08-08        1          1        300.0                 1
# 2  2022-08-08        1          1        300.0                 1
# 3  2022-08-08        1          1        300.0                 1
# 4  2022-08-08        1          1        300.0                 1
